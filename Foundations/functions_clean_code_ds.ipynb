# %% [markdown]
# ### Writing Clean Code and Conditionals Review
#
# In this notebook, you'll find tips on how to write clean code and the best practices with additional information and examples on Conditional Statements.
#
# Clean code helps you to improve communication, work faster and produce better results.
